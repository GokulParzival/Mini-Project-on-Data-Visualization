# %% [markdown]
# # Data Science Mini Project on Data Visualization

# %% [markdown]
# ![Project.jpg](attachment:Project.jpg)

# %% [markdown]
# ## Data Provided

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
pd.read_csv("StudentsPerformance (1) (1)(1).csv")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# __The given dataset consists of the following fields as column labels:__
#
#
# | Column Names                | Description                                                            |
# | ----------------------------|----------------------------------------------------------------------: |
# | gender                      | Gender of the student                                                  |
# | race/ethnicity              | Race of the Student As Group A/B/C            |                        |
# | parental level of education | What is the education Qualification of Students Parent                 |
# | lunch                       | Whether the lunch is Standard type/Free lunch or Some discounted lunch |
# | test preparation course     | Whether Student has Taken or not and Completed                         |
# | math score                  | Scores in Maths                                                        |
# | reading score               | Scores in Reading                                                      |
# | writing score               | Scores in Writing                                                      |

# %% [markdown]
# ## Objective of this Analysis

# %% [markdown]
# <img src="https://image.freepik.com/free-vector/business-management-vector_53876-44126.jpg"/>

# %% [markdown]
# __To understand how the student's performance (test scores) is affected by the other variables (Gender, Ethnicity, Parental level of education, Lunch, Test preparation course)__

# %% [markdown]
# ## Code

# %%
data_train = pd.read_csv("StudentsPerformance (1) (1)(1).csv",sep=',')

# %%
data_train
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data_train.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data_train["Total Score"]=data_train["math score"]+data_train["reading score"]+data_train["writing score"]
data_train.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
gender_count=data_train.gender.value_counts()

# %%
race_count=data_train["race/ethnicity"].value_counts()

# %%
gender_count.plot(kind='pie')

# %% [markdown]
# The count of females in the classes are greater than males

# %%
race_count.plot(kind='bar')

# %% [markdown]
# The race dominant in the class in Group C followed by Group D, Group B, Group E and Group A. Group A has the least population.

# %%
data_train["parental level of education"].value_counts().plot(kind='bar')

# %% [markdown]
# Most of the parents have attended some college. Vey few of them have recieved Master's Degree

# %%
data_train["lunch"].value_counts().plot(kind='pie')

# %% [markdown]
# A number of students in the class are provided with Standard Lunch, very few consume the free/reduced lunch

# %%
data_train["test preparation course"].value_counts().plot(kind='pie')

# %% [markdown]
# Most of the students depend upon the school's teaching method and few of them seem to have taken course

# %%
sns.pairplot(data_train)

# %%
data_train.describe()
# Out:
#        math score  reading score  writing score  Total Score
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000
# std      15.16308      14.600192      15.195657    42.771978
# min       0.00000      17.000000      10.000000    27.000000
# 25%      57.00000      59.000000      57.750000   175.000000
# 50%      66.00000      70.000000      69.000000   205.000000
# 75%      77.00000      79.000000      79.000000   233.000000
# max     100.00000     100.000000     100.000000   300.000000

# %%
a = data_train.plot(figsize=(15,8), title='Total Marks')

# %%
data_train["Total Score"].count()
# Out:
# 1000

# %%
avg = (data_train["Total Score"].sum())/1000
math_avg = (data_train["math score"].sum())/1000
read_avg = (data_train["reading score"].sum())/1000
write_avg = (data_train["writing score"].sum())/1000

# %%
print("Average marks in the data is: %.2f"%avg)
print("Average Math marks in the data is: %.2f"%math_avg)
print("Average Writing marks in the data is: %.2f"%read_avg)
print("Average Reading marks in the data is: %.2f"%write_avg)
# Out:
# Average marks in the data is: 203.31
# Average Math marks in the data is: 66.09
# Average Writing marks in the data is: 69.17
# Average Reading marks in the data is: 68.05

# %% [markdown]
# ## Analyzing Students of Group A

# %%
df = pd.DataFrame(data_train[["gender","race/ethnicity","math score","reading score","writing score","Total Score"]])
df
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 3            148
# 4            229
# ..           ...
# ...

# %%
dga=df[df["race/ethnicity"]=="group A"]
dga
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 3      male        group A          47             57             44
# 13     male        group A          78             72             70
# 14   female        group A          50             53             58
# 25     male        group A          73             74             72
# 46   female        group A          55             65             62
# ..      ...            ...         ...            ...            ...
# 974  female        group A          54             63             67
# 983  female        group A          78             87             91
# 985    male        group A          57             51             54
# 988  female        group A          44             45             45
# 994    male        group A          63             63             62
#
#      Total Score
# 3            148
# 13           220
# 14           161
# 25           219
# 46           182
# ..           ...
# ...

# %%
dga.count()
# Out:
# gender            89
# race/ethnicity    89
# math score        89
# reading score     89
# writing score     89
# Total Score       89
# dtype: int64

# %%
dgco=dga[dga["gender"]=="male"]
dgco.count()
# Out:
# gender            53
# race/ethnicity    53
# math score        53
# reading score     53
# writing score     53
# Total Score       53
# dtype: int64

# %%
dga["gender"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
print("Average total marks in the data is: %.2f"%dga["Total Score"].mean())
print("Minimum total marks in the data is:",dga["Total Score"].min())
print("Maximum total marks in the data is:",dga["Total Score"].max())
print("Minimum math marks in the data is:",dga["math score"].min())
print("Maximum math marks in the data is:",dga["math score"].max())
print("Minimum reading marks in the data is:",dga["reading score"].min())
print("Maximum reading marks in the data is:",dga["reading score"].max())
print("Minimum writing marks in the data is:",dga["writing score"].min())
print("Maximum writing marks in the data is:",dga["writing score"].max())
print("Range of total marks is from {} to {}, value is {}".format(dga["Total Score"].min(),dga["Total Score"].max(),dga["Total Score"].max()-dga["Total Score"].min()))
# Out:
# Average total marks in the data is: 188.98
# Minimum total marks in the data is: 70
# Maximum total marks in the data is: 289
# Minimum math marks in the data is: 28
# Maximum math marks in the data is: 100
# Minimum reading marks in the data is: 23
# Maximum reading marks in the data is: 100
# Minimum writing marks in the data is: 19
# Maximum writing marks in the data is: 97
# Range of total marks is from 70 to 289, value is 219

# %%
blw_avg=dga[dga["Total Score"]<avg]
blw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 3      male        group A          47             57             44
# 14   female        group A          50             53             58
# 46   female        group A          55             65             62
# 61     male        group A          39             39             34
# 62     male        group A          62             61             55
# 72   female        group A          41             51             48
# 82     male        group A          50             47             54
# 88   female        group A          58             70             67
# 112    male        group A          54             53             47
# 129  female        group A          51             49             51
# 143    male        group A          57             43             47
# 150    male        group A          62             67             69
# 250    male        group A          47             49             49
# ...

# %%
blw_avg["Total Score"].count()
# Out:
# 58

# %%
abw_avg=dga[dga["Total Score"]>=avg]
abw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 13     male        group A          78             72             70
# 25     male        group A          73             74             72
# 77     male        group A          80             78             81
# 151    male        group A          77             67             68
# 170    male        group A          72             73             74
# 228    male        group A          68             72             64
# 300    male        group A          81             78             81
# 305    male        group A          69             67             69
# 378  female        group A          71             83             77
# 423  female        group A          59             85             80
# 444    male        group A          79             82             73
# 467    male        group A          72             67             65
# 468  female        group A          77             88             85
# ...

# %%
abw_avg["Total Score"].count()
# Out:
# 31

# %%
fail=dga[dga["Total Score"]<108]
fail
# Out:
#     gender race/ethnicity  math score  reading score  writing score  \
# 327   male        group A          28             23             19
#
#      Total Score
# 327           70

# %%
high=dga[dga["Total Score"]==(dga["Total Score"].max())]
high
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 546  female        group A          92            100             97
#
#      Total Score
# 546          289

# %%
math_gA=dga[dga["math score"]>math_avg]
math_gA["math score"].count()
# Out:
# 31

# %%
read_gA=dga[dga["reading score"]>read_avg]
read_gA["reading score"].count()
# Out:
# 33

# %%
write_gA=dga[dga["writing score"]>write_avg]
write_gA["writing score"].count()
# Out:
# 31

# %% [markdown]
# ### Inference 1

# %% [markdown]
# *There are totally 89 students present in Group A. Among them 31 seem to be above average and 58 students below average. The boy to girl ratio seems to be more. Most of the students of this group seem to be good at reading than writing and math. Only one student seems to have failed with 70 marks. The topper of the class seems to have secured a total marks of 289 with 100% marks in the reading score. The average score obtained by the students is 189. Let us now discuss the factors affecting this result.*

# %%
dfc = pd.DataFrame(data_train[["race/ethnicity","parental level of education","lunch","test preparation course","Total Score"]])
dfc
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 3                      none          148
# ...

# %%
dffg=dfc[dfc["race/ethnicity"]=="group A"]
dffg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 3          group A          associate's degree  free/reduced
# 13         group A                some college      standard
# 14         group A             master's degree      standard
# 25         group A             master's degree  free/reduced
# 46         group A          associate's degree      standard
# ..             ...                         ...           ...
# 974        group A                some college      standard
# 983        group A                some college      standard
# 985        group A                 high school      standard
# 988        group A            some high school  free/reduced
# 994        group A                 high school      standard
#
#     test preparation course  Total Score
# 3                      none          148
# 13                completed          220
# 14                     none          161
# 25                     none          219
# ...

# %%
abw_avg=dffg[dffg["Total Score"]>=avg]
abw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 13         group A                some college      standard
# 25         group A             master's degree  free/reduced
# 77         group A           bachelor's degree      standard
# 151        group A           bachelor's degree      standard
# 170        group A                 high school      standard
# 228        group A            some high school  free/reduced
# 300        group A                some college  free/reduced
# 305        group A                some college      standard
# 378        group A            some high school      standard
# 423        group A            some high school      standard
# 444        group A            some high school  free/reduced
# 467        group A                 high school  free/reduced
# 468        group A                 high school  free/reduced
# 489        group A          associate's degree  free/reduced
# ...

# %%
abw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
abw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
abw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg=dffg[dffg["Total Score"]<avg]
blw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 3          group A          associate's degree  free/reduced
# 14         group A             master's degree      standard
# 46         group A          associate's degree      standard
# 61         group A            some high school  free/reduced
# 62         group A          associate's degree  free/reduced
# 72         group A          associate's degree  free/reduced
# 82         group A                some college  free/reduced
# 88         group A                some college      standard
# 112        group A          associate's degree      standard
# 129        group A           bachelor's degree      standard
# 143        group A                 high school      standard
# 150        group A            some high school      standard
# 250        group A            some high school      standard
# 296        group A            some high school      standard
# ...

# %%
blw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
blw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
fail=dffg[dffg["Total Score"]<108]
fail
# Out:
#     race/ethnicity parental level of education         lunch  \
# 327        group A                some college  free/reduced
#
#     test preparation course  Total Score
# 327                    none           70

# %%
high=dffg[dffg["Total Score"]==(dffg["Total Score"].max())]
high
# Out:
#     race/ethnicity parental level of education     lunch  \
# 546        group A            some high school  standard
#
#     test preparation course  Total Score
# 546               completed          289

# %% [markdown]
# ### Inference 2

# %% [markdown]
# *From the above data, we can infer that most of the above average students seem to have parents with education in some college, standard lunch and have completed the test preparation course. The students with total marks below average seems to have parents attending some high school, almost half of standard lunch and most of them have not completed the test preparation course. The student with lowest mark seems to have followed the same pattern as the below average student and the student with highest mark seems the same pattern as the above average student*

# %% [markdown]
# ### Solution

# %% [markdown]
# __Hence it is preferrable to have students whose parents must have attended atleast some college, the students must be provided with standard lunch and they must complete the test preparation course in order to achieve the goal of recieving the highest marks.__

# %% [markdown]
# ## Analyzing Students of Group B

# %%
df = pd.DataFrame(data_train[["gender","race/ethnicity","math score","reading score","writing score","Total Score"]])
df
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 3            148
# 4            229
# ..           ...
# ...

# %%
dgb=df[df["race/ethnicity"]=="group B"]
dgb
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 2    female        group B          90             95             93
# 5    female        group B          71             83             78
# 6    female        group B          88             95             92
# 7      male        group B          40             43             39
# ..      ...            ...         ...            ...            ...
# 969  female        group B          75             84             80
# 976    male        group B          60             62             60
# 980  female        group B           8             24             23
# 982    male        group B          79             85             86
# 991  female        group B          65             82             78
#
#      Total Score
# 0            218
# 2            278
# 5            232
# 6            275
# 7            122
# ..           ...
# ...

# %%
dgb.count()
# Out:
# gender            190
# race/ethnicity    190
# math score        190
# reading score     190
# writing score     190
# Total Score       190
# dtype: int64

# %%
dgco=dgb[dgb["gender"]=="male"]
dgco.count()
# Out:
# gender            86
# race/ethnicity    86
# math score        86
# reading score     86
# writing score     86
# Total Score       86
# dtype: int64

# %%
dgb["gender"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
print("Average total marks in the data is: %.2f"%dgb["Total Score"].mean())
print("Minimum total marks in the data is:",dgb["Total Score"].min())
print("Maximum total marks in the data is:",dgb["Total Score"].max())
print("Minimum math marks in the data is:",dgb["math score"].min())
print("Maximum math marks in the data is:",dgb["math score"].max())
print("Minimum reading marks in the data is:",dgb["reading score"].min())
print("Maximum reading marks in the data is:",dgb["reading score"].max())
print("Minimum writing marks in the data is:",dgb["writing score"].min())
print("Maximum writing marks in the data is:",dgb["writing score"].max())
print("Range of total marks is from {} to {}, value is {}".format(dgb["Total Score"].min(),dgb["Total Score"].max(),dgb["Total Score"].max()-dgb["Total Score"].min()))
# Out:
# Average total marks in the data is: 196.41
# Minimum total marks in the data is: 55
# Maximum total marks in the data is: 290
# Minimum math marks in the data is: 8
# Maximum math marks in the data is: 97
# Minimum reading marks in the data is: 24
# Maximum reading marks in the data is: 97
# Minimum writing marks in the data is: 15
# Maximum writing marks in the data is: 96
# Range of total marks is from 55 to 290, value is 235

# %%
blw_avg=dgb[dgb["Total Score"]<avg]
blw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 7      male        group B          40             43             39
# 9    female        group B          38             60             50
# 17   female        group B          18             32             28
# 26     male        group B          69             54             55
# 31   female        group B          63             65             61
# ..      ...            ...         ...            ...            ...
# 923  female        group B          54             65             65
# 944  female        group B          58             68             61
# 948    male        group B          49             50             52
# 976    male        group B          60             62             60
# 980  female        group B           8             24             23
#
#      Total Score
# 7            122
# 9            148
# 17            78
# 26           178
# 31           189
# ..           ...
# ...

# %%
blw_avg["Total Score"].count()
# Out:
# 109

# %%
abw_avg=dgb[dgb["Total Score"]>=avg]
abw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 2    female        group B          90             95             93
# 5    female        group B          71             83             78
# 6    female        group B          88             95             92
# 12   female        group B          65             81             73
# ..      ...            ...         ...            ...            ...
# 919    male        group B          91             96             91
# 946    male        group B          82             82             80
# 969  female        group B          75             84             80
# 982    male        group B          79             85             86
# 991  female        group B          65             82             78
#
#      Total Score
# 0            218
# 2            278
# 5            232
# 6            275
# 12           219
# ..           ...
# ...

# %%
abw_avg["Total Score"].count()
# Out:
# 81

# %%
fail=dgb[dgb["Total Score"]<108]
fail
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 17   female        group B          18             32             28
# 338  female        group B          24             38             27
# 596    male        group B          30             24             15
# 787  female        group B          19             38             32
# 842  female        group B          23             44             36
# 896    male        group B          36             29             27
# 980  female        group B           8             24             23
#
#      Total Score
# 17            78
# 338           89
# 596           69
# 787           89
# 842          103
# 896           92
# 980           55

# %%
high=dgb[dgb["Total Score"]==(dgb["Total Score"].max())]
high
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 855  female        group B          97             97             96
#
#      Total Score
# 855          290

# %%
math_gB=dgb[dgb["math score"]>math_avg]
math_gB["math score"].count()
# Out:
# 78

# %%
read_gB=dgb[dgb["reading score"]>read_avg]
read_gB["reading score"].count()
# Out:
# 85

# %%
write_gB=dgb[dgb["writing score"]>write_avg]
write_gB["writing score"].count()
# Out:
# 83

# %% [markdown]
# ### Inference 1

# %% [markdown]
# *There are totally 190 students present in Group B. Among them 81 seem to be above average and 109 students below average. The boy is to girl ratio is also good. Most of the students of this group seem to be good at reading skills followed by writing skills. The class seems to be poor in math score. Seven students seems to have failed with 55 marks the least mark among them. The topper of the class seems to have secured a total marks of 290. The average score of the class seem to be 196. Let us now discuss the factors affecting this result.*

# %%
dfc = pd.DataFrame(data_train[["race/ethnicity","parental level of education","lunch","test preparation course","Total Score"]])
dfc
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 3                      none          148
# ...

# %%
dffg=dfc[dfc["race/ethnicity"]=="group B"]
dffg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 2          group B             master's degree      standard
# 5          group B          associate's degree      standard
# 6          group B                some college      standard
# 7          group B                some college  free/reduced
# ..             ...                         ...           ...
# 969        group B           bachelor's degree      standard
# 976        group B                some college  free/reduced
# 980        group B                 high school  free/reduced
# 982        group B            some high school      standard
# 991        group B            some high school      standard
#
#     test preparation course  Total Score
# 0                      none          218
# 2                      none          278
# 5                      none          232
# 6                 completed          275
# ...

# %%
abw_avg=dffg[dffg["Total Score"]>=avg]
abw_avg
# Out:
#     race/ethnicity parental level of education     lunch  \
# 0          group B           bachelor's degree  standard
# 2          group B             master's degree  standard
# 5          group B          associate's degree  standard
# 6          group B                some college  standard
# 12         group B                 high school  standard
# ..             ...                         ...       ...
# 919        group B                some college  standard
# 946        group B                 high school  standard
# 969        group B           bachelor's degree  standard
# 982        group B            some high school  standard
# 991        group B            some high school  standard
#
#     test preparation course  Total Score
# 0                      none          218
# 2                      none          278
# 5                      none          232
# 6                 completed          275
# 12                     none          219
# ...

# %%
abw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
abw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
abw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg=dffg[dffg["Total Score"]<avg]
blw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 7          group B                some college  free/reduced
# 9          group B                 high school  free/reduced
# 17         group B            some high school  free/reduced
# 26         group B                some college      standard
# 31         group B                some college      standard
# ..             ...                         ...           ...
# 923        group B          associate's degree  free/reduced
# 944        group B                 high school      standard
# 948        group B            some high school  free/reduced
# 976        group B                some college  free/reduced
# 980        group B                 high school  free/reduced
#
#     test preparation course  Total Score
# 7                      none          122
# 9                      none          148
# 17                     none           78
# 26                     none          178
# ...

# %%
blw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
blw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
fail=dffg[dffg["Total Score"]<108]
fail
# Out:
#     race/ethnicity parental level of education         lunch  \
# 17         group B            some high school  free/reduced
# 338        group B            some high school  free/reduced
# 596        group B                 high school  free/reduced
# 787        group B                some college      standard
# 842        group B                 high school  free/reduced
# 896        group B                 high school  free/reduced
# 980        group B                 high school  free/reduced
#
#     test preparation course  Total Score
# 17                     none           78
# 338                    none           89
# 596                    none           69
# 787                    none           89
# 842               completed          103
# 896                    none           92
# 980                    none           55

# %%
high=dffg[dffg["Total Score"]==(dffg["Total Score"].max())]
high
# Out:
#     race/ethnicity parental level of education     lunch  \
# 855        group B           bachelor's degree  standard
#
#     test preparation course  Total Score
# 855                    none          290

# %% [markdown]
# ### Inference 2

# %% [markdown]
# *From the above data, we can infer that most of the above average students and below average students seem to have followed the same pattern that is their parents have attended high school, they are provided with standard lunch and most of them havet completed any course. The students with least marks seems to have followes the same pattern but the student with highest mark seems to have parent with bachelor's degree, standard lunch and also has not attended any test preparation course*

# %% [markdown]
# ### Solution

# %% [markdown]
# __Hence it is preferrable to have students must complete the test preparation course in order to achieve the goal of recieving the highest marks.__

# %% [markdown]
# ## Analyzing Students of Group C

# %%
df = pd.DataFrame(data_train[["gender","race/ethnicity","math score","reading score","writing score","Total Score"]])
df
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 3            148
# 4            229
# ..           ...
# ...

# %%
dgc=df[df["race/ethnicity"]=="group C"]
dgc
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 1    female        group C          69             90             88
# 4      male        group C          76             78             75
# 10     male        group C          58             54             52
# 15   female        group C          69             75             78
# 16     male        group C          88             89             86
# ..      ...            ...         ...            ...            ...
# 979  female        group C          91             95             94
# 984  female        group C          74             75             82
# 986  female        group C          40             59             51
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
#
#      Total Score
# 1            247
# 4            229
# 10           164
# 15           222
# 16           263
# ..           ...
# ...

# %%
dgc.count()
# Out:
# gender            319
# race/ethnicity    319
# math score        319
# reading score     319
# writing score     319
# Total Score       319
# dtype: int64

# %%
dgco=dgc[dgc["gender"]=="male"]
dgco.count()
# Out:
# gender            139
# race/ethnicity    139
# math score        139
# reading score     139
# writing score     139
# Total Score       139
# dtype: int64

# %%
dgc["gender"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
print("Average total marks in the data is: %.2f"%dgc["Total Score"].mean())
print("Minimum total marks in the data is:",dgc["Total Score"].min())
print("Maximum total marks in the data is:",dgc["Total Score"].max())
print("Minimum math marks in the data is:",dgc["math score"].min())
print("Maximum math marks in the data is:",dgc["math score"].max())
print("Minimum reading marks in the data is:",dgc["reading score"].min())
print("Maximum reading marks in the data is:",dgc["reading score"].max())
print("Minimum writing marks in the data is:",dgc["writing score"].min())
print("Maximum writing marks in the data is:",dgc["writing score"].max())
print("Range of total marks is from {} to {}, value is {}".format(dgc["Total Score"].min(),dgc["Total Score"].max(),dgc["Total Score"].max()-dgc["Total Score"].min()))
# Out:
# Average total marks in the data is: 201.39
# Minimum total marks in the data is: 27
# Maximum total marks in the data is: 296
# Minimum math marks in the data is: 0
# Maximum math marks in the data is: 98
# Minimum reading marks in the data is: 17
# Maximum reading marks in the data is: 100
# Minimum writing marks in the data is: 10
# Maximum writing marks in the data is: 100
# Range of total marks is from 27 to 296, value is 269

# %%
blw_avg=dgc[dgc["Total Score"]<avg]
blw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 10     male        group C          58             54             52
# 18     male        group C          46             42             46
# 19   female        group C          54             58             61
# 40     male        group C          55             61             54
# 41   female        group C          58             73             68
# ..      ...            ...         ...            ...            ...
# 967    male        group C          63             63             60
# 977    male        group C          62             65             58
# 986  female        group C          40             59             51
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
#
#      Total Score
# 10           164
# 18           134
# 19           173
# 40           170
# 41           199
# ..           ...
# ...

# %%
blw_avg["Total Score"].count()
# Out:
# 153

# %%
abw_avg=dgc[dgc["Total Score"]>=avg]
abw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 1    female        group C          69             90             88
# 4      male        group C          76             78             75
# 15   female        group C          69             75             78
# 16     male        group C          88             89             86
# 23   female        group C          69             73             73
# ..      ...            ...         ...            ...            ...
# 963  female        group C          65             76             75
# 971    male        group C          78             72             69
# 975  female        group C          64             82             77
# 979  female        group C          91             95             94
# 984  female        group C          74             75             82
#
#      Total Score
# 1            247
# 4            229
# 15           222
# 16           263
# 23           215
# ..           ...
# ...

# %%
abw_avg["Total Score"].count()
# Out:
# 166

# %%
fail=dgc[dgc["Total Score"]<108]
fail
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 59   female        group C           0             17             10
# 91     male        group C          27             34             36
# 145  female        group C          22             39             33
# 211    male        group C          35             28             27
# 555  female        group C          32             39             33
# 601  female        group C          29             29             30
#
#      Total Score
# 59            27
# 91            97
# 145           94
# 211           90
# 555          104
# 601           88

# %%
high=dgc[dgc["Total Score"]==(dgc["Total Score"].max())]
high
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 165  female        group C          96            100            100
#
#      Total Score
# 165          296

# %%
math_gC=dgc[dgc["math score"]>math_avg]
math_gC["math score"].count()
# Out:
# 140

# %%
read_gC=dgc[dgc["reading score"]>read_avg]
read_gC["reading score"].count()
# Out:
# 163

# %%
write_gC=dgc[dgc["writing score"]>write_avg]
write_gC["writing score"].count()
# Out:
# 159

# %% [markdown]
# ### Inference 1

# %% [markdown]
# *There are totally 319 students present in Group C. Among them 166 seem to be above average and 153 students below average. The boy to girl ratio seems to be little less. Most of the students of this group seem to be good at reading than writing score and a bit poor in math. Six students seems to have failed with 27 marks ast the least score. The topper of the class seems to have secured a total marks of 296 with 100% marks in the reading and writing. The average score obtained by the students is 202. Let us now discuss the factors affecting this result.*

# %%
dfc = pd.DataFrame(data_train[["race/ethnicity","parental level of education","lunch","test preparation course","Total Score"]])
dfc
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 3                      none          148
# ...

# %%
dffg=dfc[dfc["race/ethnicity"]=="group C"]
dffg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 1          group C                some college      standard
# 4          group C                some college      standard
# 10         group C          associate's degree      standard
# 15         group C            some high school      standard
# 16         group C                 high school      standard
# ..             ...                         ...           ...
# 979        group C          associate's degree      standard
# 984        group C            some high school      standard
# 986        group C          associate's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
#
#     test preparation course  Total Score
# 1                 completed          247
# 4                      none          229
# 10                     none          164
# 15                     none          222
# ...

# %%
abw_avg=dffg[dffg["Total Score"]>=avg]
abw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 1          group C                some college      standard
# 4          group C                some college      standard
# 15         group C            some high school      standard
# 16         group C                 high school      standard
# 23         group C            some high school      standard
# ..             ...                         ...           ...
# 963        group C            some high school  free/reduced
# 971        group C            some high school      standard
# 975        group C                some college      standard
# 979        group C          associate's degree      standard
# 984        group C            some high school      standard
#
#     test preparation course  Total Score
# 1                 completed          247
# 4                      none          229
# 15                     none          222
# 16                     none          263
# ...

# %%
abw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
abw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
abw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg=dffg[dffg["Total Score"]<avg]
blw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 10         group C          associate's degree      standard
# 18         group C             master's degree  free/reduced
# 19         group C          associate's degree  free/reduced
# 40         group C          associate's degree  free/reduced
# 41         group C          associate's degree      standard
# ..             ...                         ...           ...
# 967        group C                some college      standard
# 977        group C          associate's degree      standard
# 986        group C          associate's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
#
#     test preparation course  Total Score
# 10                     none          164
# 18                completed          134
# 19                     none          173
# 40                     none          170
# ...

# %%
blw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
blw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
fail=dffg[dffg["Total Score"]<108]
fail
# Out:
#     race/ethnicity parental level of education         lunch  \
# 59         group C            some high school  free/reduced
# 91         group C                 high school  free/reduced
# 145        group C                some college  free/reduced
# 211        group C                some college  free/reduced
# 555        group C                some college  free/reduced
# 601        group C                 high school      standard
#
#     test preparation course  Total Score
# 59                     none           27
# 91                     none           97
# 145                    none           94
# 211                    none           90
# 555                    none          104
# 601                    none           88

# %%
high=dffg[dffg["Total Score"]==(dffg["Total Score"].max())]
high
# Out:
#     race/ethnicity parental level of education     lunch  \
# 165        group C           bachelor's degree  standard
#
#     test preparation course  Total Score
# 165               completed          296

# %% [markdown]
# ### Inference 2

# %% [markdown]
# *From the above data, we can infer that most of the above average students seem to have parents with education with an associate degree, standard lunch and have not completed the test preparation course. The students with total marks below average seems to have parents attending some high school, almost half of standard lunch and most of them have not completed the test preparation course. The student with lowest mark seems to have followed the same pattern as the below average studentexcept the lunch to be free/reduced and the student with highest mark seems the same pattern as the above average student but with course completed*

# %% [markdown]
# ### Solution

# %% [markdown]
# __Hence it is preferrable to have students whose parents must have an associate degree or a bachelor degree, most of the students must be given standard lunch and they must complete the test preparation course in order to achieve the goal of recieving the highest marks.__

# %% [markdown]
# ## Analyzing Students of Group D

# %%
df = pd.DataFrame(data_train[["gender","race/ethnicity","math score","reading score","writing score","Total Score"]])
df
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 3            148
# 4            229
# ..           ...
# ...

# %%
dgd=df[df["race/ethnicity"]=="group D"]
dgd
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 8      male        group D          64             64             67
# 11     male        group D          40             52             43
# 20     male        group D          66             69             63
# 22     male        group D          44             54             53
# 24     male        group D          74             71             80
# ..      ...            ...         ...            ...            ...
# 989  female        group D          67             86             83
# 992  female        group D          55             76             76
# 993  female        group D          62             72             74
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 8            195
# 11           135
# 20           198
# 22           151
# 24           225
# ..           ...
# ...

# %%
dgd.count()
# Out:
# gender            262
# race/ethnicity    262
# math score        262
# reading score     262
# writing score     262
# Total Score       262
# dtype: int64

# %%
dgco=dgd[dgd["gender"]=="male"]
dgco.count()
# Out:
# gender            133
# race/ethnicity    133
# math score        133
# reading score     133
# writing score     133
# Total Score       133
# dtype: int64

# %%
dgd["gender"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
print("Average total marks in the data is: %.2f"%dgd["Total Score"].mean())
print("Minimum total marks in the data is:",dgd["Total Score"].min())
print("Maximum total marks in the data is:",dgd["Total Score"].max())
print("Minimum math marks in the data is:",dgd["math score"].min())
print("Maximum math marks in the data is:",dgd["math score"].max())
print("Minimum reading marks in the data is:",dgd["reading score"].min())
print("Maximum reading marks in the data is:",dgd["reading score"].max())
print("Minimum writing marks in the data is:",dgd["writing score"].min())
print("Maximum writing marks in the data is:",dgd["writing score"].max())
print("Range of total marks is from {} to {}, value is {}".format(dgd["Total Score"].min(),dgd["Total Score"].max(),dgd["Total Score"].max()-dgd["Total Score"].min()))
# Out:
# Average total marks in the data is: 207.54
# Minimum total marks in the data is: 93
# Maximum total marks in the data is: 297
# Minimum math marks in the data is: 26
# Maximum math marks in the data is: 100
# Minimum reading marks in the data is: 31
# Maximum reading marks in the data is: 100
# Minimum writing marks in the data is: 32
# Maximum writing marks in the data is: 100
# Range of total marks is from 93 to 297, value is 204

# %%
blw_avg=dgd[dgd["Total Score"]<avg]
blw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 8      male        group D          64             64             67
# 11     male        group D          40             52             43
# 20     male        group D          66             69             63
# 22     male        group D          44             54             53
# 33     male        group D          40             42             38
# ..      ...            ...         ...            ...            ...
# 958  female        group D          45             63             59
# 961  female        group D          48             54             53
# 964    male        group D          72             57             58
# 973  female        group D          49             65             61
# 978    male        group D          55             41             48
#
#      Total Score
# 8            195
# 11           135
# 20           198
# 22           151
# 33           120
# ..           ...
# ...

# %%
blw_avg["Total Score"].count()
# Out:
# 110

# %%
abw_avg=dgd[dgd["Total Score"]>=avg]
abw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 24     male        group D          74             71             80
# 29   female        group D          62             70             75
# 30   female        group D          69             74             74
# 36   female        group D          74             81             83
# 38   female        group D          75             90             88
# ..      ...            ...         ...            ...            ...
# 989  female        group D          67             86             83
# 992  female        group D          55             76             76
# 993  female        group D          62             72             74
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 24           225
# 29           207
# 30           217
# 36           238
# 38           253
# ..           ...
# ...

# %%
abw_avg["Total Score"].count()
# Out:
# 152

# %%
fail=dgd[dgd["Total Score"]<108]
fail
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 363  female        group D          27             34             32
# 466  female        group D          26             31             38
#
#      Total Score
# 363           93
# 466           95

# %%
high=dgd[dgd["Total Score"]==(dgd["Total Score"].max())]
high
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 179  female        group D          97            100            100
# 712  female        group D          98            100             99
#
#      Total Score
# 179          297
# 712          297

# %%
math_gD=dgd[dgd["math score"]>math_avg]
math_gD["math score"].count()
# Out:
# 146

# %%
read_gD=dgd[dgd["reading score"]>read_avg]
read_gD["reading score"].count()
# Out:
# 143

# %%
write_gD=dgd[dgd["writing score"]>write_avg]
write_gD["writing score"].count()
# Out:
# 151

# %% [markdown]
# ### Inference 1

# %% [markdown]
# *There are totally 262 students present in Group D. Among them 152 seem to be above average and 110 students below average. The boy to girl ratio seems to be more. Most of the students of this group seem to be good at reading than writing and math. Two students seems to have failed with 93 marks. The toppers of the class seems to have secured a total marks of 289 with 100% marks in the reading and writing. The average score obtained by the students is 208. Let us now discuss the factors affecting this result.*

# %%
dfc = pd.DataFrame(data_train[["race/ethnicity","parental level of education","lunch","test preparation course","Total Score"]])
dfc
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 3                      none          148
# ...

# %%
dffg=dfc[dfc["race/ethnicity"]=="group D"]
dffg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 8          group D                 high school  free/reduced
# 11         group D          associate's degree      standard
# 20         group D                 high school      standard
# 22         group D                some college      standard
# 24         group D           bachelor's degree  free/reduced
# ..             ...                         ...           ...
# 989        group D                some college  free/reduced
# 992        group D          associate's degree  free/reduced
# 993        group D           bachelor's degree  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 8                 completed          195
# 11                     none          135
# 20                     none          198
# 22                     none          151
# ...

# %%
abw_avg=dffg[dffg["Total Score"]>=avg]
abw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 24         group D           bachelor's degree  free/reduced
# 29         group D             master's degree      standard
# 30         group D                some college      standard
# 36         group D          associate's degree      standard
# 38         group D          associate's degree  free/reduced
# ..             ...                         ...           ...
# 989        group D                some college  free/reduced
# 992        group D          associate's degree  free/reduced
# 993        group D           bachelor's degree  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 24                completed          225
# 29                     none          207
# 30                     none          217
# 36                     none          238
# ...

# %%
abw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
abw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
abw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg=dffg[dffg["Total Score"]<avg]
blw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 8          group D                 high school  free/reduced
# 11         group D          associate's degree      standard
# 20         group D                 high school      standard
# 22         group D                some college      standard
# 33         group D                some college      standard
# ..             ...                         ...           ...
# 958        group D                 high school      standard
# 961        group D            some high school  free/reduced
# 964        group D                some college      standard
# 973        group D                some college  free/reduced
# 978        group D                 high school      standard
#
#     test preparation course  Total Score
# 8                 completed          195
# 11                     none          135
# 20                     none          198
# 22                     none          151
# ...

# %%
blw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
blw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
fail=dffg[dffg["Total Score"]<108]
fail
# Out:
#     race/ethnicity parental level of education         lunch  \
# 363        group D            some high school  free/reduced
# 466        group D          associate's degree  free/reduced
#
#     test preparation course  Total Score
# 363                    none           93
# 466                    none           95

# %%
high=dffg[dffg["Total Score"]==(dffg["Total Score"].max())]
high
# Out:
#     race/ethnicity parental level of education     lunch  \
# 179        group D            some high school  standard
# 712        group D                some college  standard
#
#     test preparation course  Total Score
# 179               completed          297
# 712                    none          297

# %% [markdown]
# ### Inference 2

# %% [markdown]
# *From the above data, we can infer that most of the above average students and below average students seems to have attended some college, have a standard lunch and none seem to have attended any course. The student with lowest mark seems to have their parents with a high school degree and an associate degree with free/reduced lunch and none attendend the test preparation course and the student with highest mark seems the same pattern as the above average student but one seem to have attended the test preparation course.*

# %% [markdown]
# ### Solution

# %% [markdown]
# __Hence it is preferrable to have students whose parents must have attended atleast some college, the students must be provided standard lunch and they must complete the test preparation course in order to achieve the goal of recieving better marks.__

# %% [markdown]
# ## Analyzing Students of Group E

# %%
df = pd.DataFrame(data_train[["gender","race/ethnicity","math score","reading score","writing score","Total Score"]])
df
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 3            148
# 4            229
# ..           ...
# ...

# %%
dge=df[df["race/ethnicity"]=="group E"]
dge
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 32   female        group E          56             72             65
# 34     male        group E          97             87             82
# 35     male        group E          81             81             79
# 44   female        group E          50             56             54
# 50     male        group E          53             55             48
# ..      ...            ...         ...            ...            ...
# 962  female        group E         100            100            100
# 968  female        group E          68             76             67
# 987    male        group E          81             75             76
# 990    male        group E          86             81             75
# 995  female        group E          88             99             95
#
#      Total Score
# 32           193
# 34           266
# 35           241
# 44           160
# 50           156
# ..           ...
# ...

# %%
dge.count()
# Out:
# gender            140
# race/ethnicity    140
# math score        140
# reading score     140
# writing score     140
# Total Score       140
# dtype: int64

# %%
dgco=dge[dge["gender"]=="male"]
dgco.count()
# Out:
# gender            71
# race/ethnicity    71
# math score        71
# reading score     71
# writing score     71
# Total Score       71
# dtype: int64

# %%
dge["gender"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
print("Average total marks in the data is: %.2f"%dge["Total Score"].mean())
print("Minimum total marks in the data is:",dge["Total Score"].min())
print("Maximum total marks in the data is:",dge["Total Score"].max())
print("Minimum math marks in the data is:",dge["math score"].min())
print("Maximum math marks in the data is:",dge["math score"].max())
print("Minimum reading marks in the data is:",dge["reading score"].min())
print("Maximum reading marks in the data is:",dge["reading score"].max())
print("Minimum writing marks in the data is:",dge["writing score"].min())
print("Maximum writing marks in the data is:",dge["writing score"].max())
print("Range of total marks is from {} to {}, value is {}".format(dge["Total Score"].min(),dge["Total Score"].max(),dge["Total Score"].max()-dge["Total Score"].min()))
# Out:
# Average total marks in the data is: 218.26
# Minimum total marks in the data is: 78
# Maximum total marks in the data is: 300
# Minimum math marks in the data is: 30
# Maximum math marks in the data is: 100
# Minimum reading marks in the data is: 26
# Maximum reading marks in the data is: 100
# Minimum writing marks in the data is: 22
# Maximum writing marks in the data is: 100
# Range of total marks is from 78 to 300, value is 222

# %%
blw_avg=dge[dge["Total Score"]<avg]
blw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 32   female        group E          56             72             65
# 44   female        group E          50             56             54
# 50     male        group E          53             55             48
# 76     male        group E          30             26             22
# 79   female        group E          62             68             68
# 83     male        group E          72             64             63
# 107    male        group E          66             63             64
# 137    male        group E          70             55             56
# 142  female        group E          42             55             54
# 182  female        group E          50             50             47
# 190  female        group E          66             65             69
# 197    male        group E          55             56             51
# 225  female        group E          45             56             54
# ...

# %%
blw_avg["Total Score"].count()
# Out:
# 44

# %%
abw_avg=dge[dge["Total Score"]>=avg]
abw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 34     male        group E          97             87             82
# 35     male        group E          81             81             79
# 51     male        group E          77             69             68
# 56   female        group E          82             85             86
# 60     male        group E          79             74             72
# ..      ...            ...         ...            ...            ...
# 962  female        group E         100            100            100
# 968  female        group E          68             76             67
# 987    male        group E          81             75             76
# 990    male        group E          86             81             75
# 995  female        group E          88             99             95
#
#      Total Score
# 34           266
# 35           241
# 51           214
# 56           253
# 60           225
# ..           ...
# ...

# %%
abw_avg["Total Score"].count()
# Out:
# 96

# %%
fail=dge[dge["Total Score"]<108]
fail
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 76     male        group E          30             26             22
# 895  female        group E          32             34             38
#
#      Total Score
# 76            78
# 895          104

# %%
high=dge[dge["Total Score"]==(dge["Total Score"].max())]
high
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 458  female        group E         100            100            100
# 916    male        group E         100            100            100
# 962  female        group E         100            100            100
#
#      Total Score
# 458          300
# 916          300
# 962          300

# %%
math_gE=dge[dge["math score"]>math_avg]
math_gE["math score"].count()
# Out:
# 98

# %%
read_gE=dge[dge["reading score"]>read_avg]
read_gE["reading score"].count()
# Out:
# 89

# %%
write_gE=dge[dge["writing score"]>write_avg]
write_gE["writing score"].count()
# Out:
# 88

# %% [markdown]
# ### Inference 1

# %% [markdown]
# *There are totally 140 students present in Group E. Among them 96 seem to be above average and 44 students below average. The boy to girl ratio seems to be good. Most of the students of this group seem to be good at math than writing and reading scores. Two students seems to have failed with 78 marks as the least one. The three toppers of the class seems to have secured a total marks of 300 with 100% marks in the all the subjects. The average score obtained by the students is 218. Let us now discuss the factors affecting this result.*

# %%
dfc = pd.DataFrame(data_train[["race/ethnicity","parental level of education","lunch","test preparation course","Total Score"]])
dfc
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 3                      none          148
# ...

# %%
dffg=dfc[dfc["race/ethnicity"]=="group E"]
dffg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 32         group E             master's degree  free/reduced
# 34         group E                some college      standard
# 35         group E          associate's degree      standard
# 44         group E          associate's degree  free/reduced
# 50         group E                some college      standard
# ..             ...                         ...           ...
# 962        group E          associate's degree      standard
# 968        group E          associate's degree      standard
# 987        group E            some high school      standard
# 990        group E                 high school  free/reduced
# 995        group E             master's degree      standard
#
#     test preparation course  Total Score
# 32                     none          193
# 34                     none          266
# 35                completed          241
# 44                     none          160
# ...

# %%
abw_avg=dffg[dffg["Total Score"]>=avg]
abw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 34         group E                some college      standard
# 35         group E          associate's degree      standard
# 51         group E          associate's degree  free/reduced
# 56         group E          associate's degree      standard
# 60         group E           bachelor's degree  free/reduced
# ..             ...                         ...           ...
# 962        group E          associate's degree      standard
# 968        group E          associate's degree      standard
# 987        group E            some high school      standard
# 990        group E                 high school  free/reduced
# 995        group E             master's degree      standard
#
#     test preparation course  Total Score
# 34                     none          266
# 35                completed          241
# 51                completed          214
# 56                completed          253
# ...

# %%
abw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
abw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
abw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg=dffg[dffg["Total Score"]<avg]
blw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 32         group E             master's degree  free/reduced
# 44         group E          associate's degree  free/reduced
# 50         group E                some college      standard
# 76         group E            some high school      standard
# 79         group E             master's degree      standard
# 83         group E          associate's degree      standard
# 107        group E          associate's degree      standard
# 137        group E                 high school      standard
# 142        group E                some college  free/reduced
# 182        group E                 high school      standard
# 190        group E          associate's degree      standard
# 197        group E                 high school  free/reduced
# 225        group E             master's degree  free/reduced
# 243        group E                some college      standard
# ...

# %%
blw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
blw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
fail=dffg[dffg["Total Score"]<108]
fail
# Out:
#     race/ethnicity parental level of education         lunch  \
# 76         group E            some high school      standard
# 895        group E            some high school  free/reduced
#
#     test preparation course  Total Score
# 76                     none           78
# 895                    none          104

# %%
high=dffg[dffg["Total Score"]==(dffg["Total Score"].max())]
high
# Out:
#     race/ethnicity parental level of education     lunch  \
# 458        group E           bachelor's degree  standard
# 916        group E           bachelor's degree  standard
# 962        group E          associate's degree  standard
#
#     test preparation course  Total Score
# 458                    none          300
# 916               completed          300
# 962                    none          300

# %% [markdown]
# ### Inference 2

# %% [markdown]
# *From the above data, we can infer that most of the above average students seem to have parents with education in some college or an associate degree, standard lunch and half of them have completed the test preparation course. The students with total marks below average seems to have parents have an associate degree, free/reduced lunch and most of them have not completed the test preparation course. The student with lowest mark seems to have followed the same pattern as the below average student except their parents seem to have attended high school and the student with highest mark seems the same pattern as the above average student*

# %% [markdown]
# ### Solution

# %% [markdown]
# __Hence it is preferrable to have students must be provided with standard lunch and they must complete the test preparation course in order to achieve the goal of recieving better results.__

# %% [markdown]
# ### *This marks the end of indivudual analysis of the total score with respect to the groups the students belong to. Now we will analyse the whole senario with total marks and compare the results we have obtained in summary*

# %% [markdown]
# ## Analyzing Students with respect to Total Marks

# %%
df = pd.DataFrame(data_train[["gender","race/ethnicity","math score","reading score","writing score","Total Score"]])
df
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 3            148
# 4            229
# ..           ...
# ...

# %%
df.count()
# Out:
# gender            1000
# race/ethnicity    1000
# math score        1000
# reading score     1000
# writing score     1000
# Total Score       1000
# dtype: int64

# %%
df["gender"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
df.count()
# Out:
# gender            1000
# race/ethnicity    1000
# math score        1000
# reading score     1000
# writing score     1000
# Total Score       1000
# dtype: int64

# %%
dgco=df[df["gender"]=="male"]
dgco.count()
# Out:
# gender            482
# race/ethnicity    482
# math score        482
# reading score     482
# writing score     482
# Total Score       482
# dtype: int64

# %%
print("Average total marks in the data is: %.2f"%df["Total Score"].mean())
print("Minimum total marks in the data is:",df["Total Score"].min())
print("Maximum total marks in the data is:",df["Total Score"].max())
print("Minimum math marks in the data is:",df["math score"].min())
print("Maximum math marks in the data is:",df["math score"].max())
print("Minimum reading marks in the data is:",df["reading score"].min())
print("Maximum reading marks in the data is:",df["reading score"].max())
print("Minimum writing marks in the data is:",df["writing score"].min())
print("Maximum writing marks in the data is:",df["writing score"].max())
print("Range of total marks is from {} to {}, value is {}".format(df["Total Score"].min(),df["Total Score"].max(),df["Total Score"].max()-df["Total Score"].min()))
# Out:
# Average total marks in the data is: 203.31
# Minimum total marks in the data is: 27
# Maximum total marks in the data is: 300
# Minimum math marks in the data is: 0
# Maximum math marks in the data is: 100
# Minimum reading marks in the data is: 17
# Maximum reading marks in the data is: 100
# Minimum writing marks in the data is: 10
# Maximum writing marks in the data is: 100
# Range of total marks is from 27 to 300, value is 273

# %%
blw_avg=df[df["Total Score"]<avg]
blw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 3      male        group A          47             57             44
# 7      male        group B          40             43             39
# 8      male        group D          64             64             67
# 9    female        group B          38             60             50
# 10     male        group C          58             54             52
# ..      ...            ...         ...            ...            ...
# 986  female        group C          40             59             51
# 988  female        group A          44             45             45
# 994    male        group A          63             63             62
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
#
#      Total Score
# 3            148
# 7            122
# 8            195
# 9            148
# 10           164
# ..           ...
# ...

# %%
blw_avg["Total Score"].count()
# Out:
# 474

# %%
abw_avg=df[df["Total Score"]>=avg]
abw_avg
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 4      male        group C          76             78             75
# 5    female        group B          71             83             78
# ..      ...            ...         ...            ...            ...
# 992  female        group D          55             76             76
# 993  female        group D          62             72             74
# 995  female        group E          88             99             95
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
#      Total Score
# 0            218
# 1            247
# 2            278
# 4            229
# 5            232
# ..           ...
# ...

# %%
abw_avg["Total Score"].count()
# Out:
# 526

# %%
fail=df[df["Total Score"]<108]
fail
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 17   female        group B          18             32             28
# 59   female        group C           0             17             10
# 76     male        group E          30             26             22
# 91     male        group C          27             34             36
# 145  female        group C          22             39             33
# 211    male        group C          35             28             27
# 327    male        group A          28             23             19
# 338  female        group B          24             38             27
# 363  female        group D          27             34             32
# 466  female        group D          26             31             38
# 555  female        group C          32             39             33
# 596    male        group B          30             24             15
# 601  female        group C          29             29             30
# ...

# %%
high=df[df["Total Score"]==(df["Total Score"].max())]
high
# Out:
#      gender race/ethnicity  math score  reading score  writing score  \
# 458  female        group E         100            100            100
# 916    male        group E         100            100            100
# 962  female        group E         100            100            100
#
#      Total Score
# 458          300
# 916          300
# 962          300

# %%
math_A=df[df["math score"]>math_avg]
math_A["math score"].count()
# Out:
# 493

# %%
read_gA=df[df["reading score"]>read_avg]
read_gA["reading score"].count()
# Out:
# 513

# %%
write_gA=df[df["writing score"]>write_avg]
write_gA["writing score"].count()
# Out:
# 512

# %% [markdown]
# ### Inference 1

# %% [markdown]
# *There are totally 1000 students present in the class. Among them 526 seem to be above average and 474 students below average. The boy to girl ratio seems to be little less owing to larger number of females. Most of the students of this class seem to be good at reading than writing score and are not well versed in Math. 18 students seems to have failed with 27 marks as the least marks obtained. The topper of the class seems to have secured a total marks of 300 with 100% marks in the all the scores. The average score obtained by the students is 203. Let us now discuss the factors affecting this result.*

# %%
dfc = pd.DataFrame(data_train[["race/ethnicity","parental level of education","lunch","test preparation course","Total Score"]])
dfc
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 3                      none          148
# ...

# %%
abw_avg=dfc[dfc["Total Score"]>=avg]
abw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 4          group C                some college      standard
# 5          group B          associate's degree      standard
# ..             ...                         ...           ...
# 992        group D          associate's degree  free/reduced
# 993        group D           bachelor's degree  free/reduced
# 995        group E             master's degree      standard
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  Total Score
# 0                      none          218
# 1                 completed          247
# 2                      none          278
# 4                      none          229
# ...

# %%
abw_avg["race/ethnicity"].describe()
# Out:
# count         526
# unique          5
# top       group C
# freq          166
# Name: race/ethnicity, dtype: object

# %%
abw_avg["parental level of education"].describe()
# Out:
# count                    526
# unique                     6
# top       associate's degree
# freq                     128
# Name: parental level of education, dtype: object

# %%
abw_avg["lunch"].describe()
# Out:
# count          526
# unique           2
# top       standard
# freq           392
# Name: lunch, dtype: object

# %%
abw_avg["test preparation course"].describe()
# Out:
# count      526
# unique       2
# top       none
# freq       284
# Name: test preparation course, dtype: object

# %%
abw_avg["race/ethnicity"].value_counts().plot(kind='bar')

# %%
abw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
abw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
abw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg=dfc[dfc["Total Score"]<avg]
blw_avg
# Out:
#     race/ethnicity parental level of education         lunch  \
# 3          group A          associate's degree  free/reduced
# 7          group B                some college  free/reduced
# 8          group D                 high school  free/reduced
# 9          group B                 high school  free/reduced
# 10         group C          associate's degree      standard
# ..             ...                         ...           ...
# 986        group C          associate's degree      standard
# 988        group A            some high school  free/reduced
# 994        group A                 high school      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
#
#     test preparation course  Total Score
# 3                      none          148
# 7                      none          122
# 8                 completed          195
# 9                      none          148
# ...

# %%
blw_avg["race/ethnicity"].value_counts().plot(kind='bar')

# %%
blw_avg["parental level of education"].value_counts().plot(kind='bar')

# %%
blw_avg["lunch"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
blw_avg["test preparation course"].value_counts().plot(kind='pie', fontsize = 12, autopct = '%.2f')

# %%
fail=dfc[dfc["Total Score"]<108]
fail
# Out:
#     race/ethnicity parental level of education         lunch  \
# 17         group B            some high school  free/reduced
# 59         group C            some high school  free/reduced
# 76         group E            some high school      standard
# 91         group C                 high school  free/reduced
# 145        group C                some college  free/reduced
# 211        group C                some college  free/reduced
# 327        group A                some college  free/reduced
# 338        group B            some high school  free/reduced
# 363        group D            some high school  free/reduced
# 466        group D          associate's degree  free/reduced
# 555        group C                some college  free/reduced
# 596        group B                 high school  free/reduced
# 601        group C                 high school      standard
# 787        group B                some college      standard
# ...

# %%
high=dfc[dfc["Total Score"]==(dfc["Total Score"].max())]
high
# Out:
#     race/ethnicity parental level of education     lunch  \
# 458        group E           bachelor's degree  standard
# 916        group E           bachelor's degree  standard
# 962        group E          associate's degree  standard
#
#     test preparation course  Total Score
# 458                    none          300
# 916               completed          300
# 962                    none          300

# %% [markdown]
# ### Inference 2

# %% [markdown]
# *From the above data, we can infer that most of the above average students belong to Group C, have parents with an associate degree, standard lunch and have not completed the test preparation course. The students with total marks below average belong to Group C and seem to have parents attending some high school, almost half of standard lunch and most of them have not completed the test preparation course. The student with lowest mark seems to have followed the same pattern as the below average student except free/reduced lunch and the student with highest mark seems the same pattern as the above average student but only one had completed a test prepartion course. The top scores are mostly females.*

# %% [markdown]
# ### Solution

# %% [markdown]
# __Hence it is preferrable to have students whose parents must have attended atleast some college and they must complete the test preparation course in order to achieve the goal of recieving good score.__

# %% [markdown]
# ## Summary

# %% [markdown]
# | Titles                      | Group A          | Group B          | Group C            | Group D      | Group E     |
# | ----------------------------|-----------------:|-----------------:|-------------------:|-------------:|------------:|
# | Number of Student           | 89               | 190              | 319                | 262          | 140         |
# | Males/Females               | 53/36            | 86/104           | 139/180            | 133/129      | 71/69       |
# | Average Total               | 189              | 196              | 201                | 208          | 218         |
# | Minimum Total               | 70               | 55               | 27                 | 93           | 78          |
# | Maximum Total               | 289              | 290              | 296                | 297          | 300         |
# | Above Average Students      | 31               | 81               | 166                | 152          | 96          |
# | Below Average Students      | 58               | 109              | 153                | 110          | 44          |
# | Failed Students/Least Marks | 1/70             | 7/55             | 6/27               | 2/93         | 2/78        |
# | Top Students/Highest Mark   | 1/289            | 1/290            | 1/296              | 2/297        | 3/300       |
# | Parental level Education(AA)| Some College     | Some high school | Associate Degree   | Some College | Some college|
# | Lunch(AA)                   | Standard         | Standard         | Standard           | Standard     | Standard    |
# | Test preparation(AA)        | Completed        | None             | None               | None         | Completed   |
# | Parental level Education(BA)| Some high school | Some high school | Some high school   | Some College | Associate degree |
# | Lunch(BA)                   | Standard         | Standard         | Standard           | Standard     | Standard    |
# | Test preparation(BA)        | None             | None             | None               | None         | None        |

# %% [markdown]
# | Titles                      | Total             |
# | ----------------------------|-----------------: |
# | Number of Student           | 1000              |
# | Males/Females               | 482/518           |
# | Average Total               | 203               |
# | Minimum Total               | 27                |
# | Maximum Total               | 300               |
# | Above Average Students      | 526               |
# | Below Average Students      | 474               |
# | Failed Students/Least Marks | 18/27             |
# | Top Students/Highest Mark   | 3/300             |
# | Parental level Education(AA)| Associative Degree|
# | Lunch(AA)                   | Standard          |
# | Test preparation(AA)        | None              |
# | Parental level Education(BA)| Some high school  |
# | Lunch(BA)                   | Standard          |
# | Test preparation(BA)        | None              |

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the above tables we can understand that induvidual results have resulted in better analysis than using the entire data at once. I had decided using race/ethinicity to be basis of the table using which helped me in recieving the deatiled analysis of the data given. The induvidual data grouping led to better understand the data by obtained varied results and reasoning behind it. On observing the above data we can conclude that, __students of parent having good education atleast some college degree and standard food has led to better results in most of the groups. Test Preparation are helful in few groups but most of the students do well even without the course too.__ But if a student is interested in getting high marks he must attend the test preparation course. __Group E seems to have the best results produced. Group A seems to produce the least results. Highest score is obtained by students in Group E with 300 and the lowest is obtained by Group C with 26 as total.__ Group E has the highest number of above average students followed by Group D and Group A with least number. This concludes the complete descriptive analysis of the Student Performance Data.
#
# I would really like to thank Verzeo for its great help in assisting me with data and course to complete this mini project. The project is submitted to Verzeo at __27/05/2020__.

# %% [markdown]
# ## Bibliography

# %% [markdown]
# Images were taken from :
# https://www.freepik.com/
# https://www.google.com/
#
# Data was given by verzeo through email.

# %% [markdown]
# <img src="https://img.freepik.com/free-vector/thank-you-lettering_1262-6963.jpg?size=626&ext=jpg"/>
